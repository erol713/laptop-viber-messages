# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string
# %matplotlib inline
import os
import datetime 
from tqdm import tqdm_notebook

# %%
df = pd.read_csv('finalData.csv')

# %%
df.head()
# Out:
#    Sender            Content        Date and time Label
# 0      Me            Sve ok?  2018-03-30 16:13:33    Me
# 1  Berina             Jestee  2018-03-30 16:13:46    Gf
# 2  Berina         Dosadno mi  2018-03-30 16:13:50    Gf
# 3      Me     Jos nisu dosli  2018-03-30 16:14:09    Me
# 4  Berina  Izasla sam ispred  2018-03-30 16:14:13    Gf

# %%
df.Label.value_counts()
# Out:
# Gf         152688
# Me         146065
# Family      24052
# Friends      5421
# Name: Label, dtype: int64

# %%
df['Date and time'] = pd.to_datetime(df['Date and time'])

# %%
df['Date and time'].dt.month.value_counts().head()
# Out:
# 4     55321
# 5     36204
# 9     27132
# 10    25567
# 8     24964
# Name: Date and time, dtype: int64

# %%
df['Date and time'].dt.day.value_counts().head()
# Out:
# 16    13783
# 14    13419
# 6     13416
# 12    13091
# 7     12584
# Name: Date and time, dtype: int64

# %%
df['Date and time'].dt.hour.value_counts().head()
# Out:
# 22    34420
# 23    33800
# 21    27169
# 11    21418
# 12    21055
# Name: Date and time, dtype: int64

# %%
plt.figure(figsize=(24, 8))
ax = sns.countplot( df['Date and time'].dt.month, hue = df['Label'])
ax.set_xlabel("Monthly")
# Out:
# Text(0.5, 0, 'Monthly')

# %%
plt.figure(figsize=(16, 6))
ax = sns.countplot( df['Date and time'].dt.day, hue = df['Label'])
ax.set_xlabel("Daily")
# Out:
# Text(0.5, 0, 'Daily')

# %%
plt.figure(figsize=(16, 6))
ax = sns.countplot( df['Date and time'].dt.hour, hue = df['Label'])
ax.set_xlabel("Hourly")
# Out:
# Text(0.5, 0, 'Hourly')
